# %% [markdown]
# # IMPORTS

# %%
# !pip install ccxt
import ccxt
import pandas as pd
import time
from datetime import datetime
import myconfig
import math
import xlrd

# %% [markdown]
# # INITIALIZE

# %%
exchange = ccxt.binance({
    "apiKey": myconfig.API_KEY,
    "secret": myconfig.API_SECRET
})

#exchange = ccxt.binance ({
     
#    'apiKey': myconfig.API_KEY,
#    'secret': myconfig.API_SECRET,
#    'rateLimit': 10000,  # unified exchange property
#    'options': {
#        'adjustForTimeDifference': True,  # exchange-specific option
#   }
#})
#exchange.options['adjustForTimeDifference'] = False

# %%
# markets = exchange.fetchMarkets()
# market_symbols = [market['symbol'] for market in markets]
# print(f'No. of market symbols: {len(market_symbols)}')
# print(f'Sample:{market_symbols[0:5]}')
# Out:
# No. of market symbols: 2089
# Sample:['ETH/BTC', 'LTC/BTC', 'BNB/BTC', 'NEO/BTC', 'QTUM/ETH']

# %%
path = ('.\mybuy.xls')
trade_combinations = pd.read_excel(path)
trade_combinations

# %%
trade_combinations.info()

# %% [markdown]
# # STEP 1: GET ALL THE CRYPTO COMBINATIONS FOR USDT

# %%
# def get_crypto_combinations(market_symbols, base):
#     combinations = []
#     for sym1 in market_symbols:
        
#         sym1_token1 = sym1.split('/')[0]
#         sym1_token2 = sym1.split('/')[1]
        
#         if (sym1_token2 == base):
#             for sym2 in market_symbols:
#                 sym2_token1 = sym2.split('/')[0]
#                 sym2_token2 = sym2.split('/')[1]
#                 if (sym1_token1 == sym2_token2):
#                     for sym3 in market_symbols:
#                         sym3_token1 = sym3.split('/')[0]
#                         sym3_token2 = sym3.split('/')[1]
#                         if((sym2_token1 == sym3_token1) and (sym3_token2 == sym1_token2)):
#                             combination = {
#                                 'base':sym1_token2,
#                                 'intermediate':sym1_token1,
#                                 'ticker':sym2_token1,
#                             }
#                             combinations.append(combination)
                

#     return combinations
        
# wx_combinations_usdt = get_crypto_combinations(market_symbols,'USDT')

# %%
# print(f'No. of crypto combinations: {len(wx_combinations_usdt)}')

# cominations_df = pd.DataFrame(wx_combinations_usdt)
# cominations_df.sample(10)
# Out:
# No. of crypto combinations: 1276
#      base intermediate ticker
# 505  USDT          BNB    XRP
# 903  USDT         BUSD  OCEAN
# 472  USDT          BNB    BCC
# 167  USDT          BTC    DIA
# 355  USDT          ETH    VEN
# 628  USDT          BNB     NU
# 552  USDT          BNB   CTXC
# 82   USDT          BTC   MITH
# 759  USDT          PAX    ONE
# 30   USDT          BTC  STORJ

# %% [markdown]
# # STEP 2: PERFORM TRIANGULAR ARBITRAGE

# %% [markdown]
# ## Utility method to fetch the current ticker price

# %%
def fetch_current_ticker_price(ticker):
    current_ticker_details = exchange.fetch_ticker(ticker)
    ticker_price = current_ticker_details['close'] if current_ticker_details is not None else None
    return ticker_price

# %%
def check_if_float_zero(value):
    return math.isclose(value, 0.0, abs_tol=1e-9)

# %%
def fetch_ticker_bid(ticker):
    current_ticker_details = exchange.fetch_ticker(ticker)
    ticker_price = current_ticker_details['bid'] if current_ticker_details is not None else None
    return ticker_price

# %%
def fetch_ticker_ask(ticker):
    current_ticker_details = exchange.fetch_ticker(ticker)
    ticker_price = current_ticker_details['ask'] if current_ticker_details is not None else None
    return ticker_price

# %%
def ticker_is_reasonable_percent(scrip, percentage):
    current_ask = fetch_ticker_ask(scrip)
    current_bid = fetch_ticker_bid(scrip)
    current_price = fetch_current_ticker_price(scrip)
    cond1 = current_ask is not None and not check_if_float_zero(current_ask)
    cond2 = current_bid is not None and not check_if_float_zero(current_bid)
    if cond1 and cond2:
        bid_ask_diff = (current_ask / current_bid - 1) * 100
        cond3 = bid_ask_diff <= percentage
    else:
        cond3 =False
        bid_ask_diff = None
    return (cond1 and cond2 and cond3, current_ask, current_price, current_bid, bid_ask_diff)

# %%
def ticker_is_reasonable(scrip):
    print('___________________________________________________________________________________')
    print('Scrip:', scrip)
    is_valid, ask_prev, current_price, bid_prev, bid_ask_diff = ticker_is_reasonable_percent(scrip, 0.14)
    if is_valid:
        print('bid:',bid_prev,'curr_price: ',current_price,'ask:',ask_prev,'bid_ask_diff:', bid_ask_diff,'%, \nEnter')
        print('___________________________________________________________________________________')
        return True
    is_valid, ask_prev, current_price, bid_prev, bid_ask_diff = ticker_is_reasonable_percent(scrip, 1)
    if is_valid:
        print('bid:',bid_prev,'curr_price: ',current_price,'ask:',ask_prev,'bid_ask_diff:', bid_ask_diff,'%, \nWait 3 sec')
        time.sleep(3)
        is_valid, ask_new, current_price, bid_new, bid_ask_diff = ticker_is_reasonable_percent(scrip, 1)
        print('Last_bid:',bid_prev,'New_bid:',bid_new,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'New_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'%')
        if ask_new != ask_prev and bid_new != bid_prev:
            print('Last_bid:',bid_prev,'New_bid:',bid_new,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'New_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'% \nEnter')
            print('___________________________________________________________________________________')
            return True
        print('Last_bid:',bid_prev,'New_bid:',bid_new,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'New_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'% \nWait 3 sec')
        ask_prev, bid_prev = ask_new, bid_prev
        time.sleep(3)
        is_valid, ask_new, current_price, bid_new, bid_ask_diff = ticker_is_reasonable_percent(scrip, 1)
        if ask_new != ask_prev and bid_new != bid_prev:
            print('Last_bid:',bid_prev,'New_bid:',bid_new,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'New_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'% \nEnter')
            print('___________________________________________________________________________________')
            return True
    print('Last_bid:',bid_prev,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'% \nSkip')
    print('___________________________________________________________________________________')
    return False

# %% [markdown]
# ## Triangular Arbitrage

# %% [markdown]
# ### Check with new conditions

# %%
def check_buy_buy_sell(scrip1, scrip2, scrip3, initial_investment):
    
    ## SCRIP1
    investment_amount1 = initial_investment
    current_price1 = fetch_current_ticker_price(scrip1)
    final_price = 0
    scrip_prices = {}

    if ticker_is_reasonable(scrip1) and current_price1 is not None and not check_if_float_zero(current_price1):
        buy_quantity1 = round(investment_amount1 / current_price1, 8)
        
        # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
        time.sleep(1)
        ## SCRIP2
        investment_amount2 = buy_quantity1     
        current_price2 = fetch_current_ticker_price(scrip2)
        if ticker_is_reasonable(scrip2) and current_price2 is not None and not check_if_float_zero(current_price2):
            buy_quantity2 = round(investment_amount2 / current_price2, 8)
            
            # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
            time.sleep(1)
            ## SCRIP3
            investment_amount3 = buy_quantity2     
            current_price3 = fetch_current_ticker_price(scrip3)
            if ticker_is_reasonable(scrip3) and current_price3 is not None and not check_if_float_zero(current_price3):
                sell_quantity3 = buy_quantity2
                final_price = round(sell_quantity3 * current_price3,3)
                scrip_prices = {scrip1 : current_price1, scrip2 : current_price2, scrip3 : current_price3}
                
    return final_price, scrip_prices

# %% [markdown]
# ### Check with old conditions

# %%
# def check_buy_buy_sell(scrip1, scrip2, scrip3, initial_investment):
    
#     ## SCRIP1
#     investment_amount1 = initial_investment
#     current_price1 = fetch_current_ticker_price(scrip1)
#     final_price = 0
#     scrip_prices = {}

#     if current_price1 is not None and not check_if_float_zero(current_price1):
#         buy_quantity1 = round(investment_amount1 / current_price1, 8)

#         # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
#         time.sleep(1)
#         # SCRIP2
#         investment_amount2 = buy_quantity1     
#         current_price2 = fetch_current_ticker_price(scrip2)
#         if current_price2 is not None and not check_if_float_zero(current_price2):
#             buy_quantity2 = round(investment_amount2 / current_price2, 8)

#             # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
#             time.sleep(1)
#             ## SCRIP3
#             investment_amount3 = buy_quantity2     
#             current_price3 = fetch_current_ticker_price(scrip3)
#             if current_price3 is not None and not check_if_float_zero(current_price3):
#                 sell_quantity3 = buy_quantity2
#                 final_price = round(sell_quantity3 * current_price3,3)
#                 scrip_prices = {scrip1 : current_price1, scrip2 : current_price2, scrip3 : current_price3}
                
#     return final_price, scrip_prices

# %% [markdown]
# ### Check with new conditions

# %%
def check_buy_sell_sell(scrip1, scrip2, scrip3, initial_investment):
    
    ## SCRIP1
    investment_amount1 = initial_investment
    current_price1 = fetch_current_ticker_price(scrip1)
    final_price = 0
    scrip_prices = {}
    if ticker_is_reasonable(scrip1) and current_price1 is not None and not check_if_float_zero(current_price1):
        buy_quantity1 = round(investment_amount1 / current_price1, 8)
        
        # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
        time.sleep(1)
        ## SCRIP2
        investment_amount2 = buy_quantity1     
        current_price2 = fetch_current_ticker_price(scrip2)
        if ticker_is_reasonable(scrip2) and current_price2 is not None and not check_if_float_zero(current_price2):
            sell_quantity2 = buy_quantity1
            sell_price2 = round(sell_quantity2 * current_price2,8)
            
            # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
            time.sleep(1)
            ## SCRIP1
            investment_amount3 = sell_price2     
            current_price3 = fetch_current_ticker_price(scrip3)
            if ticker_is_reasonable(scrip3) and current_price3 is not None and not check_if_float_zero(current_price3):
                sell_quantity3 = sell_price2
                final_price = round(sell_quantity3 * current_price3,3)
                scrip_prices = {scrip1 : current_price1, scrip2 : current_price2, scrip3 : current_price3}
    return final_price,scrip_prices

# %% [markdown]
# ### Check with old conditions

# %%
# def check_buy_sell_sell(scrip1, scrip2, scrip3, initial_investment):
#     ## SCRIP1
#     investment_amount1 = initial_investment
#     current_price1 = fetch_current_ticker_price(scrip1)
#     crurent_ask1 = fetch_ticker_ask(scrip1)
#     current_bid1 = fetch_ticker_bid(scrip1)
#     bid_ask_diff = (current_ask1 / current_bid1 - 1) * 100 
#     final_price = 0
#     scrip_prices = {}
#     if current_price1 is not None and not check_if_float_zero(current_price1):
#         buy_quantity1 = round(investment_amount1 / current_price1, 8)
        
#         # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
#         time.sleep(1)
#         ## SCRIP2
#         investment_amount2 = buy_quantity1     
#         current_price2 = fetch_current_ticker_price(scrip2)
#         if current_price2 is not None and not check_if_float_zero(current_price2):
#             sell_quantity2 = buy_quantity1
#             sell_price2 = round(sell_quantity2 * current_price2,8)
            
#             # TRY WITHOUT SLEEP IF THE EXCHANGE DOES NOT THROW RATE LIMIT EXCEPTIONS
#             time.sleep(1)
#             ## SCRIP1
#             investment_amount3 = sell_price2     
#             current_price3 = fetch_current_ticker_price(scrip3)
#             if current_price3 is not None and not check_if_float_zero(current_price3):
#                 sell_quantity3 = sell_price2
#                 final_price = round(sell_quantity3 * current_price3,3)
#                 scrip_prices = {scrip1 : current_price1, scrip2 : current_price2, scrip3 : current_price3}
#     return final_price,scrip_prices

# %%
def check_profit_loss(total_price_after_sell,initial_investment,transaction_brokerage, min_profit):
    apprx_brokerage = transaction_brokerage * initial_investment/100 * 3
    min_profitable_price = initial_investment + apprx_brokerage + min_profit
    profit_loss = round(total_price_after_sell - min_profitable_price,3)
    return profit_loss

# %% [markdown]
# # STEP 3: PLACE THE TRADE ORDERS

# %%
def place_buy_order(scrip, quantity, limit):
    order = exchange.create_limit_buy_order(scrip, quantity, limit)
    return order

def place_sell_order(scrip, quantity, limit):
    order = exchange.create_limit_sell_order(scrip, quantity, limit)
    return order 

def place_trade_orders(type, scrip1, scrip2, scrip3, initial_amount, scrip_prices):
    final_amount = 0.0
    if type == 'BUY_BUY_SELL':
        s1_quantity = initial_amount/scrip_prices[scrip1]
        place_buy_order(scrip1, s1_quantity, scrip_prices[scrip1])
        
        s2_quantity = s1_quantity/scrip_prices[scrip2]
        place_buy_order(scrip2, s2_quantity, scrip_prices[scrip2])
        
        s3_quantity = s2_quantity
        place_sell_order(scrip3, s3_quantity, scrip_prices[scrip3])
        
    elif type == 'BUY_SELL_SELL':
        s1_quantity = initial_amount/scrip_prices[scrip1]
        place_buy_order(scrip1, s1_quantity, scrip_prices[scrip1])
        
        s2_quantity = s1_quantity
        place_sell_order(scrip2, s2_quantity, scrip_prices[scrip2])
        
        s3_quantity = s2_quantity * scrip_prices[scrip2]
        place_sell_order(scrip3, s3_quantity, scrip_prices[scrip3])
        
        
    return final_amount

# %% [markdown]
# Sample order from exchange immediately after execution:
# {'info': {'id': '2490462375', 'symbol': 'btcusdt', 'type': 'limit', 'side': 'buy', 'status': 'wait', 'price': '43201.0', 'origQty': '0.002314', 'executedQty': '0.0', 'createdTime': '1646302254000', 'updatedTime': '1646302254000'}, 'id': '2490462375', 'clientOrderId': None, 'timestamp': 1646302254000, 'datetime': '2022-03-03T10:10:54.000Z', 'lastTradeTimestamp': 1646302254000, 'status': 'open', 'symbol': 'BTC/USDT', 'type': 'limit', 'timeInForce': None, 'postOnly': None, 'side': 'buy', 'price': 43201.0, 'amount': None, 'filled': 0.0, 'remaining': None, 'cost': 0.0, 'fee': None, 'average': None, 'trades': [], 'fees': []}

# %% [markdown]
# # STEP 4: WRAPPING IT TOGETHER

# %%
def perform_triangular_arbitrage(scrip1, scrip2, scrip3, arbitrage_type,initial_investment, 
                               transaction_brokerage, min_profit):
    final_price = 0.0
    
    if(arbitrage_type == 'BUY_BUY_SELL'):
        # Check this combination for triangular arbitrage: scrip1 - BUY, scrip2 - BUY, scrip3 - SELL
        final_price, scrip_prices = check_buy_buy_sell(scrip1, scrip2, scrip3,initial_investment)
        
    elif(arbitrage_type == 'BUY_SELL_SELL'):
        # Check this combination for triangular arbitrage: scrip1 - BUY, scrip2 - SELL, scrip3 - SELL
        final_price, scrip_prices = check_buy_sell_sell(scrip1, scrip2, scrip3,initial_investment)
        
    profit_loss = check_profit_loss(final_price,initial_investment, transaction_brokerage, min_profit)
    
    print(
        f"*{datetime.now().strftime('%H:%M:%S')}\t{final_price}\t{scrip_prices}\t"\
              f"{arbitrage_type}\t{scrip1}\t{scrip2}\t{scrip3}\tProfit/Loss: {round(final_price-initial_investment,3)} ")
        
    if profit_loss>0:
        print(
            f"**PROFIT{datetime.now().strftime('%H:%M:%S')}\t{final_price}\t{scrip_prices}\t"\
              f"{arbitrage_type}\t{scrip1}\t{scrip2}\t{scrip3}\tProfit/Loss: {round(final_price-initial_investment,3)} ")
        
        # UNCOMMENT THIS LINE TO PLACE THE ORDERS
        # place_trade_orders(arbitrage_type, scrip1, scrip2, scrip3, initial_investment, scrip_prices)

# %% [markdown]
# ### New loop

# %%
INVESTMENT_AMOUNT_DOLLARS = 100
MIN_PROFIT_DOLLARS = 0.5
BROKERAGE_PER_TRANSACTION_PERCENT = 0.075

# UNCOMMENT THE WHILE LOOP TO RUN THIS LOOP CONTINUOUSLY
# while(1):
for i in range(len(trade_combinations)):

    s1 = trade_combinations.sym1[i]
    s2 = trade_combinations.sym2[i]
    s3 = trade_combinations.sym3[i]
    trans_type = trade_combinations.Type[i]

    # Check triangular arbitrage for buy-buy-sell 
    perform_triangular_arbitrage(s1,s2,s3,trans_type,INVESTMENT_AMOUNT_DOLLARS,
                              BROKERAGE_PER_TRANSACTION_PERCENT, MIN_PROFIT_DOLLARS)
    # Sleep to avoid rate limit on api calls (RateLimitExceeded exception)
    time.sleep(1)

# %% [markdown]
# ### Old loop

# %%
# INVESTMENT_AMOUNT_DOLLARS = 100
# MIN_PROFIT_DOLLARS = 0.5
# BROKERAGE_PER_TRANSACTION_PERCENT = 0.075


# # UNCOMMENT THE WHILE LOOP TO RUN THIS LOOP CONTINUOUSLY
# #while(1):
# for combination in wx_combinations_usdt:

#     base = combination['base']
#     intermediate = combination['intermediate']
#     ticker = combination['ticker']


#     s1 = f'{intermediate}/{base}'    # Eg: BTC/USDT
#     s2 = f'{ticker}/{intermediate}'  # Eg: ETH/BTC
#     s3 = f'{ticker}/{base}'          # Eg: ETH/USDT 
# # Вывести через табуляцию , начиная с * все, что есть + цену

#     # Check triangular arbitrage for buy-buy-sell 
#     perform_triangular_arbitrage(s1,s2,s3,'BUY_BUY_SELL',INVESTMENT_AMOUNT_DOLLARS,
#                               BROKERAGE_PER_TRANSACTION_PERCENT, MIN_PROFIT_DOLLARS)
#     # Sleep to avoid rate limit on api calls (RateLimitExceeded exception)
#     time.sleep(1) 
#     # Check triangular arbitrage for buy-sell-sell 
#     perform_triangular_arbitrage(s3,s2,s1,'BUY_SELL_SELL',INVESTMENT_AMOUNT_DOLLARS,
#                               BROKERAGE_PER_TRANSACTION_PERCENT, MIN_PROFIT_DOLLARS)
#     time.sleep(1)
# Out:
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21424.62 curr_price:  21424.7 ask: 21425.71 bid_ask_diff: 0.005087604820985803 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETH/BTC
# bid: 0.076363 curr_price:  0.076363 ask: 0.076364 bid_ask_diff: 0.0013095347223046616 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETH/USDT
# bid: 1636.1 curr_price:  1635.99 ask: 1636.11 bid_ask_diff: 0.0006112095837673692 %,
# Enter
# ___________________________________________________________________________________
# *19:47:22	100.001	{'BTC/USDT': 21425.0, 'ETH/BTC': 0.076363, 'ETH/USDT': 1636.1}	BUY_BUY_SELL	BTC/USDT	ETH/BTC	ETH/USDT	Profit/Loss: 0.001
# ___________________________________________________________________________________
# Scrip: ETH/USDT
# bid: 1635.99 curr_price:  1635.99 ask: 1636.0 bid_ask_diff: 0.0006112506800048934 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETH/BTC
# bid: 0.076363 curr_price:  0.076364 ask: 0.076364 bid_ask_diff: 0.0013095347223046616 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21424.76 curr_price:  21426.22 ask: 21426.52 bid_ask_diff: 0.008214794471461673 %,
# Enter
# ___________________________________________________________________________________
# *19:47:28	100.012	{'ETH/USDT': 1636.0, 'ETH/BTC': 0.076363, 'BTC/USDT': 21426.56}	BUY_SELL_SELL	ETH/USDT	ETH/BTC	BTC/USDT	Profit/Loss: 0.012
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21423.58 curr_price:  21424.52 ask: 21425.03 bid_ask_diff: 0.006768243216104253 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LTC/BTC
# bid: 0.002643 curr_price:  0.002643 ask: 0.002644 bid_ask_diff: 0.03783579265985715 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LTC/USDT
# bid: 56.61 curr_price:  56.61 ask: 56.62 bid_ask_diff: 0.017664723547072825 %,
# Enter
# ___________________________________________________________________________________
# *19:47:34	100.012	{'BTC/USDT': 21423.86, 'LTC/BTC': 0.002643, 'LTC/USDT': 56.63}	BUY_BUY_SELL	BTC/USDT	LTC/BTC	LTC/USDT	Profit/Loss: 0.012
# ___________________________________________________________________________________
# Scrip: LTC/USDT
# bid: 56.61 curr_price:  56.61 ask: 56.62 bid_ask_diff: 0.017664723547072825 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LTC/BTC
# bid: 0.002643 curr_price:  0.002643 ask: 0.002644 bid_ask_diff: 0.03783579265985715 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21413.09 curr_price:  21411.76 ask: 21416.07 bid_ask_diff: 0.013916721033724322 %,
# Enter
# ___________________________________________________________________________________
# *19:47:42	99.988	{'LTC/USDT': 56.61, 'LTC/BTC': 0.002643, 'BTC/USDT': 21416.29}	BUY_SELL_SELL	LTC/USDT	LTC/BTC	BTC/USDT	Profit/Loss: -0.012
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21413.28 curr_price:  21414.48 ask: 21414.32 bid_ask_diff: 0.004856799145214197 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BNB/BTC
# bid: 0.013857 curr_price:  0.013858 ask: 0.013858 bid_ask_diff: 0.0072165692429848605 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BNB/USDT
# bid: 296.7 curr_price:  296.8 ask: 296.8 bid_ask_diff: 0.033704078193474984 %,
# Enter
# ___________________________________________________________________________________
# *19:47:49	100.017	{'BTC/USDT': 21413.57, 'BNB/BTC': 0.013858, 'BNB/USDT': 296.8}	BUY_BUY_SELL	BTC/USDT	BNB/BTC	BNB/USDT	Profit/Loss: 0.017
# ___________________________________________________________________________________
# Scrip: BNB/USDT
# bid: 296.7 curr_price:  296.7 ask: 296.8 bid_ask_diff: 0.033704078193474984 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BNB/BTC
# bid: 0.013857 curr_price:  0.013857 ask: 0.013858 bid_ask_diff: 0.0072165692429848605 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21412.5 curr_price:  21412.51 ask: 21414.22 bid_ask_diff: 0.008032691185055896 %,
# Enter
# ___________________________________________________________________________________
# *19:47:56	99.978	{'BNB/USDT': 296.8, 'BNB/BTC': 0.013857, 'BTC/USDT': 21414.0}	BUY_SELL_SELL	BNB/USDT	BNB/BTC	BTC/USDT	Profit/Loss: -0.022
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21414.4 curr_price:  21415.22 ask: 21415.6 bid_ask_diff: 0.005603705917489599 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: NEO/BTC
# bid: 0.000455 curr_price:  0.000456 ask: 0.000456 bid_ask_diff: 0.219780219780219 %,
# Wait 3 sec
# Last_bid: 0.000455 New_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456 New_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Last_bid: 0.000455 New_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456 New_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Wait 3 sec
# Last_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Skip
# ___________________________________________________________________________________
# *19:48:08	0	{}	BUY_BUY_SELL	BTC/USDT	NEO/BTC	NEO/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: NEO/USDT
# bid: 9.75 curr_price:  9.75 ask: 9.76 bid_ask_diff: 0.10256410256410664 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: NEO/BTC
# bid: 0.000455 curr_price:  0.000456 ask: 0.000456 bid_ask_diff: 0.219780219780219 %,
# Wait 3 sec
# Last_bid: 0.000455 New_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456 New_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Last_bid: 0.000455 New_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456 New_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Wait 3 sec
# Last_bid: 0.000455
# curr_price:  0.000456
# Last_ask: 0.000456
# bid_ask_diff: 0.219780219780219 %
# Skip
# ___________________________________________________________________________________
# *19:48:21	0	{}	BUY_SELL_SELL	NEO/USDT	NEO/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21411.69 curr_price:  21412.26 ask: 21412.1 bid_ask_diff: 0.0019148418457293204 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BCC/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:48:26	0	{}	BUY_BUY_SELL	BTC/USDT	BCC/BTC	BCC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BCC/USDT
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:48:30	0	{}	BUY_SELL_SELL	BCC/USDT	BCC/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21414.68 curr_price:  21414.67 ask: 21415.91 bid_ask_diff: 0.005743723464468609 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: MCO/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:48:35	0	{}	BUY_BUY_SELL	BTC/USDT	MCO/BTC	MCO/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: MCO/USDT
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:48:38	0	{}	BUY_SELL_SELL	MCO/USDT	MCO/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21411.12 curr_price:  21412.31 ask: 21413.27 bid_ask_diff: 0.01004151114001317 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: WTC/BTC
# bid: 1.237e-05 curr_price:  1.237e-05 ask: 1.244e-05 bid_ask_diff: 0.5658852061438902 %,
# Wait 3 sec
# Last_bid: 1.237e-05 New_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05 New_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Last_bid: 1.237e-05 New_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05 New_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Wait 3 sec
# Last_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Skip
# ___________________________________________________________________________________
# *19:48:53	0	{}	BUY_BUY_SELL	BTC/USDT	WTC/BTC	WTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: WTC/USDT
# bid: 0.2647 curr_price:  0.2654 ask: 0.265 bid_ask_diff: 0.11333585190782536 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: WTC/BTC
# bid: 1.237e-05 curr_price:  1.237e-05 ask: 1.244e-05 bid_ask_diff: 0.5658852061438902 %,
# Wait 3 sec
# Last_bid: 1.237e-05 New_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05 New_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Last_bid: 1.237e-05 New_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05 New_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Wait 3 sec
# Last_bid: 1.237e-05
# curr_price:  1.237e-05
# Last_ask: 1.244e-05
# bid_ask_diff: 0.5658852061438902 %
# Skip
# ___________________________________________________________________________________
# *19:49:06	0	{}	BUY_SELL_SELL	WTC/USDT	WTC/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21413.95 curr_price:  21414.25 ask: 21414.08 bid_ask_diff: 0.0006070808981961662 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LRC/BTC
# bid: 1.771e-05 curr_price:  1.772e-05 ask: 1.772e-05 bid_ask_diff: 0.05646527385656519 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LRC/USDT
# bid: 0.3793 curr_price:  0.3793 ask: 0.3794 bid_ask_diff: 0.026364355391517158 %,
# Enter
# ___________________________________________________________________________________
# *19:49:13	99.954	{'BTC/USDT': 21414.99, 'LRC/BTC': 1.772e-05, 'LRC/USDT': 0.3793}	BUY_BUY_SELL	BTC/USDT	LRC/BTC	LRC/USDT	Profit/Loss: -0.046
# ___________________________________________________________________________________
# Scrip: LRC/USDT
# bid: 0.3793 curr_price:  0.3793 ask: 0.3794 bid_ask_diff: 0.026364355391517158 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LRC/BTC
# bid: 1.771e-05 curr_price:  1.772e-05 ask: 1.772e-05 bid_ask_diff: 0.05646527385656519 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21411.75 curr_price:  21412.38 ask: 21412.96 bid_ask_diff: 0.005651102782344708 %,
# Enter
# ___________________________________________________________________________________
# *19:49:19	100.036	{'LRC/USDT': 0.3793, 'LRC/BTC': 1.772e-05, 'BTC/USDT': 21412.93}	BUY_SELL_SELL	LRC/USDT	LRC/BTC	BTC/USDT	Profit/Loss: 0.036
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21412.53 curr_price:  21413.38 ask: 21413.3 bid_ask_diff: 0.003596025317897933 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: QTUM/BTC
# bid: 0.000162 curr_price:  0.0001622 ask: 0.0001622 bid_ask_diff: 0.12345679012346622 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: QTUM/USDT
# bid: 3.469 curr_price:  3.469 ask: 3.471 bid_ask_diff: 0.057653502450283334 %,
# Enter
# ___________________________________________________________________________________
# *19:49:25	99.882	{'BTC/USDT': 21412.4, 'QTUM/BTC': 0.0001622, 'QTUM/USDT': 3.469}	BUY_BUY_SELL	BTC/USDT	QTUM/BTC	QTUM/USDT	Profit/Loss: -0.118
# ___________________________________________________________________________________
# Scrip: QTUM/USDT
# bid: 3.469 curr_price:  3.469 ask: 3.471 bid_ask_diff: 0.057653502450283334 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: QTUM/BTC
# bid: 0.000162 curr_price:  0.0001622 ask: 0.0001622 bid_ask_diff: 0.12345679012346622 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21414.98 curr_price:  21415.42 ask: 21415.31 bid_ask_diff: 0.001540977390601661 %,
# Enter
# ___________________________________________________________________________________
# *19:49:31	100.133	{'QTUM/USDT': 3.469, 'QTUM/BTC': 0.0001622, 'BTC/USDT': 21415.64}	BUY_SELL_SELL	QTUM/USDT	QTUM/BTC	BTC/USDT	Profit/Loss: 0.133
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21414.55 curr_price:  21415.53 ask: 21415.25 bid_ask_diff: 0.0032688055551011175 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: OMG/BTC
# bid: 9.05e-05 curr_price:  9.07e-05 ask: 9.07e-05 bid_ask_diff: 0.22099447513810322 %,
# Wait 3 sec
# Last_bid: 9.05e-05 New_bid: 9.05e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05 New_ask: 9.07e-05
# bid_ask_diff: 0.22099447513810322 %
# Last_bid: 9.05e-05 New_bid: 9.05e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05 New_ask: 9.07e-05
# bid_ask_diff: 0.22099447513810322 %
# Wait 3 sec
# Last_bid: 9.05e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05
# bid_ask_diff: 0.22099447513810322 %
# Skip
# ___________________________________________________________________________________
# *19:49:45	0	{}	BUY_BUY_SELL	BTC/USDT	OMG/BTC	OMG/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: OMG/USDT
# bid: 1.938 curr_price:  1.94 ask: 1.939 bid_ask_diff: 0.05159958720331037 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: OMG/BTC
# bid: 9.05e-05 curr_price:  9.07e-05 ask: 9.07e-05 bid_ask_diff: 0.22099447513810322 %,
# Wait 3 sec
# Last_bid: 9.05e-05 New_bid: 9.04e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05 New_ask: 9.07e-05
# bid_ask_diff: 0.33185840707963266 %
# Last_bid: 9.05e-05 New_bid: 9.04e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05 New_ask: 9.07e-05
# bid_ask_diff: 0.33185840707963266 %
# Wait 3 sec
# Last_bid: 9.05e-05
# curr_price:  9.07e-05
# Last_ask: 9.07e-05
# bid_ask_diff: 0.33185840707963266 %
# Skip
# ___________________________________________________________________________________
# *19:49:59	0	{}	BUY_SELL_SELL	OMG/USDT	OMG/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21403.66 curr_price:  21403.08 ask: 21405.47 bid_ask_diff: 0.008456497627040704 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ZRX/BTC
# bid: 1.423e-05 curr_price:  1.425e-05 ask: 1.425e-05 bid_ask_diff: 0.14054813773718422 %,
# Wait 3 sec
# Last_bid: 1.423e-05 New_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05 New_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Last_bid: 1.423e-05 New_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05 New_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Wait 3 sec
# Last_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Skip
# ___________________________________________________________________________________
# *19:50:12	0	{}	BUY_BUY_SELL	BTC/USDT	ZRX/BTC	ZRX/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: ZRX/USDT
# bid: 0.3049 curr_price:  0.3049 ask: 0.3051 bid_ask_diff: 0.06559527714002922 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ZRX/BTC
# bid: 1.423e-05 curr_price:  1.425e-05 ask: 1.425e-05 bid_ask_diff: 0.14054813773718422 %,
# Wait 3 sec
# Last_bid: 1.423e-05 New_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05 New_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Last_bid: 1.423e-05 New_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05 New_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Wait 3 sec
# Last_bid: 1.423e-05
# curr_price:  1.425e-05
# Last_ask: 1.425e-05
# bid_ask_diff: 0.14054813773718422 %
# Skip
# ___________________________________________________________________________________
# *19:50:24	0	{}	BUY_SELL_SELL	ZRX/USDT	ZRX/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21411.75 curr_price:  21414.98 ask: 21409.51 bid_ask_diff: -0.010461545646678339 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: STRAT/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:50:29	0	{}	BUY_BUY_SELL	BTC/USDT	STRAT/BTC	STRAT/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: STRAT/USDT
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:50:32	0	{}	BUY_SELL_SELL	STRAT/USDT	STRAT/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21412.38 curr_price:  21412.38 ask: 21413.31 bid_ask_diff: 0.004343281783714126 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: KNC/BTC
# bid: 8.747e-05 curr_price:  8.748e-05 ask: 8.751e-05 bid_ask_diff: 0.04572996455927125 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: KNC/USDT
# bid: 1.873 curr_price:  1.873 ask: 1.874 bid_ask_diff: 0.05339028296851289 %,
# Enter
# ___________________________________________________________________________________
# *19:50:41	99.988	{'BTC/USDT': 21413.22, 'KNC/BTC': 8.748e-05, 'KNC/USDT': 1.873}	BUY_BUY_SELL	BTC/USDT	KNC/BTC	KNC/USDT	Profit/Loss: -0.012
# ___________________________________________________________________________________
# Scrip: KNC/USDT
# bid: 1.873 curr_price:  1.873 ask: 1.874 bid_ask_diff: 0.05339028296851289 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: KNC/BTC
# bid: 8.748e-05 curr_price:  8.748e-05 ask: 8.751e-05 bid_ask_diff: 0.03429355281205915 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21413.86 curr_price:  21413.91 ask: 21414.36 bid_ask_diff: 0.0023349363449609584 %,
# Enter
# ___________________________________________________________________________________
# *19:50:50	100.013	{'KNC/USDT': 1.873, 'KNC/BTC': 8.748e-05, 'BTC/USDT': 21413.45}	BUY_SELL_SELL	KNC/USDT	KNC/BTC	BTC/USDT	Profit/Loss: 0.013
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21412.55 curr_price:  21412.2 ask: 21413.28 bid_ask_diff: 0.0034092156235399074 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: FUN/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:50:56	0	{}	BUY_BUY_SELL	BTC/USDT	FUN/BTC	FUN/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: FUN/USDT
# bid: 0.0079 curr_price:  0.00791 ask: 0.00791 bid_ask_diff: 0.12658227848101333 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: FUN/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:51:01	0	{}	BUY_SELL_SELL	FUN/USDT	FUN/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21412.33 curr_price:  21413.05 ask: 21413.31 bid_ask_diff: 0.004576802244304901 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: IOTA/BTC
# bid: 1.369e-05 curr_price:  1.37e-05 ask: 1.37e-05 bid_ask_diff: 0.07304601899196239 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: IOTA/USDT
# bid: 0.2931 curr_price:  0.2931 ask: 0.2932 bid_ask_diff: 0.03411804844761779 %,
# Enter
# ___________________________________________________________________________________
# *19:51:08	99.915	{'BTC/USDT': 21412.37, 'IOTA/BTC': 1.37e-05, 'IOTA/USDT': 0.2931}	BUY_BUY_SELL	BTC/USDT	IOTA/BTC	IOTA/USDT	Profit/Loss: -0.085
# ___________________________________________________________________________________
# Scrip: IOTA/USDT
# bid: 0.2931 curr_price:  0.2931 ask: 0.2933 bid_ask_diff: 0.06823609689525778 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: IOTA/BTC
# bid: 1.369e-05 curr_price:  1.37e-05 ask: 1.37e-05 bid_ask_diff: 0.07304601899196239 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21414.28 curr_price:  21414.45 ask: 21415.16 bid_ask_diff: 0.004109407367414164 %,
# Enter
# ___________________________________________________________________________________
# *19:51:14	100.098	{'IOTA/USDT': 0.2931, 'IOTA/BTC': 1.37e-05, 'BTC/USDT': 21415.19}	BUY_SELL_SELL	IOTA/USDT	IOTA/BTC	BTC/USDT	Profit/Loss: 0.098
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21413.69 curr_price:  21413.7 ask: 21415.94 bid_ask_diff: 0.01050729696749908 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LINK/BTC
# bid: 0.000335 curr_price:  0.0003351 ask: 0.0003351 bid_ask_diff: 0.029850746268667017 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LINK/USDT
# bid: 7.172 curr_price:  7.173 ask: 7.173 bid_ask_diff: 0.013943112102632327 %,
# Enter
# ___________________________________________________________________________________
# *19:51:20	99.957	{'BTC/USDT': 21414.66, 'LINK/BTC': 0.0003351, 'LINK/USDT': 7.173}	BUY_BUY_SELL	BTC/USDT	LINK/BTC	LINK/USDT	Profit/Loss: -0.043
# ___________________________________________________________________________________
# Scrip: LINK/USDT
# bid: 7.172 curr_price:  7.173 ask: 7.173 bid_ask_diff: 0.013943112102632327 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: LINK/BTC
# bid: 0.000335 curr_price:  0.0003351 ask: 0.0003351 bid_ask_diff: 0.029850746268667017 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21408.01 curr_price:  21408.01 ask: 21408.52 bid_ask_diff: 0.0023822858827182714 %,
# Enter
# ___________________________________________________________________________________
# *19:51:27	100.009	{'LINK/USDT': 7.173, 'LINK/BTC': 0.0003351, 'BTC/USDT': 21407.46}	BUY_SELL_SELL	LINK/USDT	LINK/BTC	BTC/USDT	Profit/Loss: 0.009
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21406.01 curr_price:  21406.49 ask: 21407.71 bid_ask_diff: 0.007941694879143313 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: XVG/BTC
# Last_bid: 0.0
# curr_price:  0.0
# Last_ask: 0.0
# bid_ask_diff: None %
# Skip
# ___________________________________________________________________________________
# *19:51:32	0	{}	BUY_BUY_SELL	BTC/USDT	XVG/BTC	XVG/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: XVG/USDT
# bid: 0.00322 curr_price:  0.00322 ask: 0.00323 bid_ask_diff: 0.31055900621117516 %,
# Wait 3 sec
# Last_bid: 0.00322 New_bid: 0.00322
# curr_price:  0.00322
# Last_ask: 0.00323 New_ask: 0.00323
# bid_ask_diff: 0.31055900621117516 %
# Last_bid: 0.00322 New_bid: 0.00322
# curr_price:  0.00322
# Last_ask: 0.00323 New_ask: 0.00323
# bid_ask_diff: 0.31055900621117516 %
# Wait 3 sec
# Last_bid: 0.00322
# curr_price:  0.00322
# Last_ask: 0.00323
# bid_ask_diff: 0.31055900621117516 %
# Skip
# ___________________________________________________________________________________
# *19:51:43	0	{}	BUY_SELL_SELL	XVG/USDT	XVG/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21404.84 curr_price:  21404.84 ask: 21405.74 bid_ask_diff: 0.004204656516937355 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: MTL/BTC
# bid: 5.726e-05 curr_price:  5.742e-05 ask: 5.742e-05 bid_ask_diff: 0.27942717429270125 %,
# Wait 3 sec
# Last_bid: 5.726e-05 New_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05 New_ask: 5.742e-05
# bid_ask_diff: 0.27942717429270125 %
# Last_bid: 5.726e-05 New_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05 New_ask: 5.742e-05
# bid_ask_diff: 0.27942717429270125 %
# Wait 3 sec
# Last_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05
# bid_ask_diff: 0.27942717429270125 %
# Skip
# ___________________________________________________________________________________
# *19:51:56	0	{}	BUY_BUY_SELL	BTC/USDT	MTL/BTC	MTL/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: MTL/USDT
# bid: 1.226 curr_price:  1.227 ask: 1.227 bid_ask_diff: 0.08156606851550396 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: MTL/BTC
# bid: 5.726e-05 curr_price:  5.742e-05 ask: 5.742e-05 bid_ask_diff: 0.27942717429270125 %,
# Wait 3 sec
# Last_bid: 5.726e-05 New_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05 New_ask: 5.742e-05
# bid_ask_diff: 0.27942717429270125 %
# Last_bid: 5.726e-05 New_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05 New_ask: 5.742e-05
# bid_ask_diff: 0.27942717429270125 %
# Wait 3 sec
# Last_bid: 5.726e-05
# curr_price:  5.742e-05
# Last_ask: 5.742e-05
# bid_ask_diff: 0.2619629758994213 %
# Skip
# ___________________________________________________________________________________
# *19:52:09	0	{}	BUY_SELL_SELL	MTL/USDT	MTL/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21410.06 curr_price:  21410.95 ask: 21410.77 bid_ask_diff: 0.0033161980863116725 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: EOS/BTC
# bid: 8.38e-05 curr_price:  8.38e-05 ask: 8.39e-05 bid_ask_diff: 0.11933174224343368 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: EOS/USDT
# bid: 1.796 curr_price:  1.797 ask: 1.797 bid_ask_diff: 0.055679287305121505 %,
# Enter
# ___________________________________________________________________________________
# *19:52:16	100.156	{'BTC/USDT': 21410.61, 'EOS/BTC': 8.38e-05, 'EOS/USDT': 1.797}	BUY_BUY_SELL	BTC/USDT	EOS/BTC	EOS/USDT	Profit/Loss: 0.156
# ___________________________________________________________________________________
# Scrip: EOS/USDT
# bid: 1.795 curr_price:  1.796 ask: 1.796 bid_ask_diff: 0.05571030640669772 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: EOS/BTC
# bid: 8.38e-05 curr_price:  8.38e-05 ask: 8.39e-05 bid_ask_diff: 0.11933174224343368 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21410.67 curr_price:  21411.26 ask: 21411.69 bid_ask_diff: 0.004763979828759091 %,
# Enter
# ___________________________________________________________________________________
# *19:52:23	99.849	{'EOS/USDT': 1.797, 'EOS/BTC': 8.38e-05, 'BTC/USDT': 21411.55}	BUY_SELL_SELL	EOS/USDT	EOS/BTC	BTC/USDT	Profit/Loss: -0.151
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21406.23 curr_price:  21405.18 ask: 21406.92 bid_ask_diff: 0.0032233606758413913 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETC/BTC
# bid: 0.001581 curr_price:  0.00158 ask: 0.001582 bid_ask_diff: 0.06325110689437974 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETC/USDT
# bid: 33.85 curr_price:  33.85 ask: 33.86 bid_ask_diff: 0.029542097488910457 %,
# Enter
# ___________________________________________________________________________________
# *19:52:29	100.085	{'BTC/USDT': 21405.78, 'ETC/BTC': 0.00158, 'ETC/USDT': 33.85}	BUY_BUY_SELL	BTC/USDT	ETC/BTC	ETC/USDT	Profit/Loss: 0.085
# ___________________________________________________________________________________
# Scrip: ETC/USDT
# bid: 33.85 curr_price:  33.86 ask: 33.86 bid_ask_diff: 0.029542097488910457 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ETC/BTC
# bid: 0.001581 curr_price:  0.00158 ask: 0.001582 bid_ask_diff: 0.06325110689437974 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21406.27 curr_price:  21406.24 ask: 21406.96 bid_ask_diff: 0.003223354652615029 %,
# Enter
# ___________________________________________________________________________________
# *19:52:36	99.917	{'ETC/USDT': 33.85, 'ETC/BTC': 0.00158, 'BTC/USDT': 21406.24}	BUY_SELL_SELL	ETC/USDT	ETC/BTC	BTC/USDT	Profit/Loss: -0.083
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21408.98 curr_price:  21409.95 ask: 21408.67 bid_ask_diff: -0.0014479905161346451 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: DNT/BTC
# bid: 2.17e-06 curr_price:  2.18e-06 ask: 2.18e-06 bid_ask_diff: 0.4608294930875445 %,
# Wait 3 sec
# Last_bid: 2.17e-06 New_bid: 2.17e-06
# curr_price:  2.18e-06
# Last_ask: 2.18e-06 New_ask: 2.18e-06
# bid_ask_diff: 0.4608294930875445 %
# Last_bid: 2.17e-06 New_bid: 2.17e-06
# curr_price:  2.18e-06
# Last_ask: 2.18e-06 New_ask: 2.18e-06
# bid_ask_diff: 0.4608294930875445 %
# Wait 3 sec
# Last_bid: 2.17e-06
# curr_price:  2.18e-06
# Last_ask: 2.18e-06
# bid_ask_diff: 0.4608294930875445 %
# Skip
# ___________________________________________________________________________________
# *19:52:51	0	{}	BUY_BUY_SELL	BTC/USDT	DNT/BTC	DNT/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: DNT/USDT
# bid: 0.0466 curr_price:  0.0466 ask: 0.0467 bid_ask_diff: 0.21459227467810482 %,
# Wait 3 sec
# Last_bid: 0.0466 New_bid: 0.0466
# curr_price:  0.0466
# Last_ask: 0.0467 New_ask: 0.0467
# bid_ask_diff: 0.21459227467810482 %
# Last_bid: 0.0466 New_bid: 0.0466
# curr_price:  0.0466
# Last_ask: 0.0467 New_ask: 0.0467
# bid_ask_diff: 0.21459227467810482 %
# Wait 3 sec
# Last_bid: 0.0466
# curr_price:  0.0466
# Last_ask: 0.0467
# bid_ask_diff: 0.21459227467810482 %
# Skip
# ___________________________________________________________________________________
# *19:53:01	0	{}	BUY_SELL_SELL	DNT/USDT	DNT/BTC	BTC/USDT	Profit/Loss: -100
# ___________________________________________________________________________________
# Scrip: BTC/USDT
# bid: 21430.03 curr_price:  21430.76 ask: 21429.75 bid_ask_diff: -0.0013065777322740502 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ZEC/BTC
# bid: 0.00304 curr_price:  0.00304 ask: 0.003042 bid_ask_diff: 0.06578947368420796 %,
# Enter
# ___________________________________________________________________________________
# ___________________________________________________________________________________
# Scrip: ZEC/USDT
# bid: 65.1 curr_price:  65.1 ask: 65.2 bid_ask_diff: 0.1536098310291889 %,
# Wait 3 sec
# Last_bid: 65.1 New_bid: 65.1
# curr_price:  65.1
# Last_ask: 65.2 New_ask: 65.2
# bid_ask_diff: 0.1536098310291889 %
# Last_bid: 65.1 New_bid: 65.1
# curr_price:  65.1
# Last_ask: 65.2 New_ask: 65.2
# bid_ask_diff: 0.1536098310291889 %
# Wait 3 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-6119bd74d186> in <module>
#      19
#      20     # Check triangular arbitrage for buy-buy-sell
# ---> 21     perform_triangular_arbitrage(s1,s2,s3,'BUY_BUY_SELL',INVESTMENT_AMOUNT_DOLLARS,
#      22                               BROKERAGE_PER_TRANSACTION_PERCENT, MIN_PROFIT_DOLLARS)
#      23     # Sleep to avoid rate limit on api calls (RateLimitExceeded exception)
#
# <ipython-input-51-d57246537ca8> in perform_triangular_arbitrage(scrip1, scrip2, scrip3, arbitrage_type, initial_investment, transaction_brokerage, min_profit)
#       5     if(arbitrage_type == 'BUY_BUY_SELL'):
#       6         # Check this combination for triangular arbitrage: scrip1 - BUY, scrip2 - BUY, scrip3 - SELL
# ----> 7         final_price, scrip_prices = check_buy_buy_sell(scrip1, scrip2, scrip3,initial_investment)
#       8
#       9     elif(arbitrage_type == 'BUY_SELL_SELL'):
#
# <ipython-input-41-473c9a36bdc7> in check_buy_buy_sell(scrip1, scrip2, scrip3, initial_investment)
#      23             investment_amount3 = buy_quantity2
#      24             current_price3 = fetch_current_ticker_price(scrip3)
# ---> 25             if ticker_is_reasonable(scrip3) and current_price3 is not None and not check_if_float_zero(current_price3):
#      26                 sell_quantity3 = buy_quantity2
#      27                 final_price = round(sell_quantity3 * current_price3,3)
#
# <ipython-input-40-7b75b3b3b20c> in ticker_is_reasonable(scrip)
#      20         ask_prev, bid_prev = ask_new, bid_prev
#      21         time.sleep(3)
# ---> 22         is_valid, ask_new, current_price, bid_new, bid_ask_diff = ticker_is_reasonable_percent(scrip, 1)
#      23         if ask_new != ask_prev and bid_new != bid_prev:
#      24             print('Last_bid:',bid_prev,'New_bid:',bid_new,'\ncurr_price: ',current_price,'\nLast_ask:',ask_prev,'New_ask:',ask_prev,'\nbid_ask_diff:', bid_ask_diff,'% \nEnter')
#
# <ipython-input-48-45e9ecae38d8> in ticker_is_reasonable_percent(scrip, percentage)
#       1 def ticker_is_reasonable_percent(scrip, percentage):
# ----> 2     current_ask = fetch_ticker_ask(scrip)
#       3     current_bid = fetch_ticker_bid(scrip)
#       4     current_price = fetch_current_ticker_price(scrip)
#       5     cond1 = current_ask is not None and not check_if_float_zero(current_ask)
#
# <ipython-input-38-6d5053b04651> in fetch_ticker_ask(ticker)
#       1 def fetch_ticker_ask(ticker):
# ----> 2     current_ticker_details = exchange.fetch_ticker(ticker)
#       3     ticker_price = current_ticker_details['ask'] if current_ticker_details is not None else None
#       4     return ticker_price
#
# ~\anaconda3\lib\site-packages\ccxt\binance.py in fetch_ticker(self, symbol, params)
#    2242         elif market['inverse']:
#    2243             method = 'dapiPublicGetTicker24hr'
# -> 2244         response = getattr(self, method)(self.extend(request, params))
#    2245         if isinstance(response, list):
#    2246             firstTicker = self.safe_value(response, 0, {})
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in inner(_self, params, context)
#     498                 if context is not None:
#     499                     inner_kwargs['context'] = params
# --> 500                 return entry(_self, **inner_kwargs)
#     501             return inner
#     502         to_bind = partialer()
#
# ~\anaconda3\lib\site-packages\ccxt\binance.py in request(self, path, api, method, params, headers, body, config, context)
#    5506
#    5507     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}, context={}):
# -> 5508         response = self.fetch2(path, api, method, params, headers, body, config, context)
#    5509         # a workaround for {"code":-2015,"msg":"Invalid API-key, IP, or permissions for action."}
#    5510         if (api == 'private') or (api == 'wapi'):
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch2(self, path, api, method, params, headers, body, config, context)
#    2622         self.lastRestRequestTimestamp = self.milliseconds()
#    2623         request = self.sign(path, api, method, params, headers, body)
# -> 2624         return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#    2625
#    2626     def request(self, path, api='public', method='GET', params={}, headers=None, body=None, config={}, context={}):
#
# ~\anaconda3\lib\site-packages\ccxt\base\exchange.py in fetch(self, url, method, headers, body)
#     592         json_response = None
#     593         try:
# --> 594             response = self.session.request(
#     595                 method,
#     596                 url,
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
